# %% [markdown]
# <a href="https://colab.research.google.com/github/pksvv/lang-transformers/blob/main/Haystack_Neural_Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://raw.githubusercontent.com/yashprakash13/datasets/master/arxiv_short.csv

# %%
# !pip install git+https://github.com/deepset-ai/haystack.git
# !pip install urllib3==1.25.4
# !pip install grpcio-tools==1.34.1 grpcio==1.34.1
# !pip install sentence-transformers
# Out:
# ...
#   Cloning https://github.com/deepset-ai/haystack.git to /tmp/pip-req-build-e63sa6cs
#   Running command git clone -q https://github.com/deepset-ai/haystack.git /tmp/pip-req-build-e63sa6cs
# ...
#      |████████████████████████████████| 43 kB 1.1 MB/s
# ...
#      |████████████████████████████████| 14.1 MB 10.9 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 14.5 MB/s
# ...
#      |████████████████████████████████| 51 kB 599 kB/s
# ...
#      |████████████████████████████████| 54 kB 3.1 MB/s
# ...
#      |████████████████████████████████| 79 kB 5.4 MB/s
# ...
#      |████████████████████████████████| 321 kB 39.9 MB/s
# ...
#      |████████████████████████████████| 359 kB 10.6 MB/s
# ...
#      |████████████████████████████████| 85 kB 2.6 MB/s
# ...
#      |████████████████████████████████| 981 kB 38.1 MB/s
# ...
#      |████████████████████████████████| 3.0 MB 12.9 MB/s
# ...
#      |████████████████████████████████| 78 kB 4.1 MB/s
# ...
#      |████████████████████████████████| 5.6 MB 32.7 MB/s
# ...

# %%
# !nvidia-smi
# Out:
# Mon Jan  3 18:28:26 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8    28W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
